# %% [markdown]
# <a href="https://colab.research.google.com/github/Latamila/Mineracao/blob/main/McDonaldsSQL_PYTHON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Install & load sqlite3
#!pip install sqlite3  ##Uncomment the code to install sqlite3
import sqlite3

# %%
# Connecting to sqlite
# connection object
conn = sqlite3.connect('INSTRUCTOR.db')

# %%
# cursor object
cursor_obj = conn.cursor()

# %%
# cursor object
cursor_obj = conn.cursor()

# %%
# Drop the table if already exists.
cursor_obj.execute("DROP TABLE IF EXISTS INSTRUCTOR")

# %%
# Creating table
table = """ create table IF NOT EXISTS INSTRUCTOR(ID INTEGER PRIMARY KEY NOT NULL, FNAME VARCHAR(20), LNAME VARCHAR(20), CITY VARCHAR(20), CCODE CHAR(2));"""

cursor_obj.execute(table)

print("Table is Ready")
# Out:
# Table is Ready

# %%
cursor_obj.execute('''insert into INSTRUCTOR values (1, 'Rav', 'Ahuja', 'TORONTO', 'CA')''')

# %%
cursor_obj.execute('''insert into INSTRUCTOR values (2, 'Raul', 'Chong', 'Markham', 'CA'), (3, 'Hima', 'Vasudevan', 'Chicago', 'US')''')

# %%
statement = '''SELECT * FROM INSTRUCTOR'''
cursor_obj.execute(statement)

print("All the data")
output_all = cursor_obj.fetchall()
for row_all in output_all:
  print(row_all)
# Out:
# All the data
# (1, 'Rav', 'Ahuja', 'TORONTO', 'CA')
# (2, 'Raul', 'Chong', 'Markham', 'CA')
# (3, 'Hima', 'Vasudevan', 'Chicago', 'US')

# %%
## Fetch few rows from the table
statement = '''SELECT * FROM INSTRUCTOR'''
cursor_obj.execute(statement)

print("All the data")
# If you want to fetch few rows from the table we use fetchmany(numberofrows) and mention the number how many rows you want to fetch
output_many = cursor_obj.fetchmany(2)
for row_many in output_many:
  print(row_many)
# Out:
# All the data
# (1, 'Rav', 'Ahuja', 'TORONTO', 'CA')
# (2, 'Raul', 'Chong', 'Markham', 'CA')

# %%
# Fetch only FNAME from the table
statement = '''SELECT FNAME FROM INSTRUCTOR'''
cursor_obj.execute(statement)

print("All the data")
output_column = cursor_obj.fetchall()
for fetch in output_column:
  print(fetch)
# Out:
# All the data
# ('Rav',)
# ('Raul',)
# ('Hima',)

# %%
query_update='''update INSTRUCTOR set CITY='MOOSETOWN' where FNAME="Rav"'''
cursor_obj.execute(query_update)

# %%
statement = '''SELECT * FROM INSTRUCTOR'''
cursor_obj.execute(statement)

print("All the data")
output1 = cursor_obj.fetchmany(2)
for row in output1:
  print(row)
# Out:
# All the data
# (1, 'Rav', 'Ahuja', 'MOOSETOWN', 'CA')
# (2, 'Raul', 'Chong', 'Markham', 'CA')

# %%
import pandas as pd
#retrieve the query results into a pandas dataframe
df = pd.read_sql_query("select * from instructor;", conn)

#print the dataframe
df
# Out:
#    ID FNAME      LNAME       CITY CCODE
# 0   1   Rav      Ahuja  MOOSETOWN    CA
# 1   2  Raul      Chong    Markham    CA
# 2   3  Hima  Vasudevan    Chicago    US

# %%
#print just the LNAME for first row in the pandas data frame
df.LNAME[0]
# Out:
# 'Ahuja'

# %%
df.shape
# Out:
# (3, 5)

# %%
# Close the connection
conn.close()

# %%
# %ls
# Out:
# INSTRUCTOR.db  sample_data/

# %%
# %pwd
# Out:
# '/content'

# %%
# %%writefile myfile.txt
# Out:
# Writing myfile.txt

# %%
# %%writefile myfile.txt
# <statement 1>
# <statement 2>
# <statement 3>
# <statement 4>
# Out:
# Overwriting myfile.txt

# %%
# %%timeit
# Out:
# UsageError: %%timeit is a cell magic, but the cell body is empty. Did you mean the line magic %timeit (single %)?

# %%
# %timeit

# %%
# %%HTML
# <h1>Hello world!</h1>
# Out:
# <h1>Hello world!</h1>

# %%
# %%javascript
# alert('Hello world!')

# %%
# %%bash
# echo Hello world
# Out:
# Hello world

# %%
# !pip install --user ipython-sql
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 7.9 MB/s eta 0:00:00
# ...

# %%
# %load_ext sql

# %%
import sqlite3

# %%
conn = sqlite3.connect('HR.db')

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql sqlite:///HR.db

# %%
# %sql SELECT * FROM Employee
# Out:
#  * sqlite:///HR.db
# (sqlite3.OperationalError) no such table: Employee
# [SQL: SELECT * FROM Employee]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
import csv, sqlite3

con = sqlite3.connect("SQLiteMagic.db")
cur = con.cursor()

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql sqlite:///SQLiteMagic.db

# %%
# %%sql
#
# CREATE TABLE INTERNATIONAL_STUDENT_TEST_SCORES (
# 	country VARCHAR(50),
# 	first_name VARCHAR(50),
# 	last_name VARCHAR(50),
# 	test_score INT
# );
# INSERT INTO INTERNATIONAL_STUDENT_TEST_SCORES (country, first_name, last_name, test_score)
# VALUES
# ('United States', 'Marshall', 'Bernadot', 54),
# ('Ghana', 'Celinda', 'Malkin', 51),
# ('Ukraine', 'Guillermo', 'Furze', 53),
# ('Greece', 'Aharon', 'Tunnow', 48),
# ('Russia', 'Bail', 'Goodwin', 46),
# ('Poland', 'Cole', 'Winteringham', 49),
# ('Sweden', 'Emlyn', 'Erricker', 55),
# ('Russia', 'Cathee', 'Sivewright', 49),
# ('China', 'Barny', 'Ingerson', 57),
# ('Uganda', 'Sharla', 'Papaccio', 55),
# ('China', 'Stella', 'Youens', 51),
# ('Poland', 'Julio', 'Buesden', 48),
# ('United States', 'Tiffie', 'Cosely', 58),
# ('Poland', 'Auroora', 'Stiffell', 45),
# ('China', 'Clarita', 'Huet', 52),
# ('Poland', 'Shannon', 'Goulden', 45),
# ('Philippines', 'Emylee', 'Privost', 50),
# ('France', 'Madelina', 'Burk', 49),
# ('China', 'Saunderson', 'Root', 58),
# ('Indonesia', 'Bo', 'Waring', 55),
# ('China', 'Hollis', 'Domotor', 45),
# ('Russia', 'Robbie', 'Collip', 46),
# ('Philippines', 'Davon', 'Donisi', 46),
# ('China', 'Cristabel', 'Radeliffe', 48),
# ('China', 'Wallis', 'Bartleet', 58),
# ('Moldova', 'Arleen', 'Stailey', 38),
# ('Ireland', 'Mendel', 'Grumble', 58),
# ('China', 'Sallyann', 'Exley', 51),
# ('Mexico', 'Kain', 'Swaite', 46),
# ('Indonesia', 'Alonso', 'Bulteel', 45),
# ('Armenia', 'Anatol', 'Tankus', 51),
# ('Indonesia', 'Coralyn', 'Dawkins', 48),
# ('China', 'Deanne', 'Edwinson', 45),
# ('China', 'Georgiana', 'Epple', 51),
# ('Portugal', 'Bartlet', 'Breese', 56),
# ('Azerbaijan', 'Idalina', 'Lukash', 50),
# ('France', 'Livvie', 'Flory', 54),
# ('Malaysia', 'Nonie', 'Borit', 48),
# ('Indonesia', 'Clio', 'Mugg', 47),
# ('Brazil', 'Westley', 'Measor', 48),
# ('Philippines', 'Katrinka', 'Sibbert', 51),
# ('Poland', 'Valentia', 'Mounch', 50),
# ('Norway', 'Sheilah', 'Hedditch', 53),
# ('Papua New Guinea', 'Itch', 'Jubb', 50),
# ('Latvia', 'Stesha', 'Garnson', 53),
# ('Canada', 'Cristionna', 'Wadmore', 46),
# ('China', 'Lianna', 'Gatward', 43),
# ('Guatemala', 'Tanney', 'Vials', 48),
# ('France', 'Alma', 'Zavittieri', 44),
# ('China', 'Alvira', 'Tamas', 50),
# ('United States', 'Shanon', 'Peres', 45),
# ('Sweden', 'Maisey', 'Lynas', 53),
# ('Indonesia', 'Kip', 'Hothersall', 46),
# ('China', 'Cash', 'Landis', 48),
# ('Panama', 'Kennith', 'Digance', 45),
# ('China', 'Ulberto', 'Riggeard', 48),
# ('Switzerland', 'Judy', 'Gilligan', 49),
# ('Philippines', 'Tod', 'Trevaskus', 52),
# ('Brazil', 'Herold', 'Heggs', 44),
# ('Latvia', 'Verney', 'Note', 50),
# ('Poland', 'Temp', 'Ribey', 50),
# ('China', 'Conroy', 'Egdal', 48),
# ('Japan', 'Gabie', 'Alessandone', 47),
# ('Ukraine', 'Devlen', 'Chaperlin', 54),
# ('France', 'Babbette', 'Turner', 51),
# ('Czech Republic', 'Virgil', 'Scotney', 52),
# ('Tajikistan', 'Zorina', 'Bedow', 49),
# ('China', 'Aidan', 'Rudeyeard', 50),
# ('Ireland', 'Saunder', 'MacLice', 48),
# ('France', 'Waly', 'Brunstan', 53),
# ('China', 'Gisele', 'Enns', 52),
# ('Peru', 'Mina', 'Winchester', 48),
# ('Japan', 'Torie', 'MacShirrie', 50),
# ('Russia', 'Benjamen', 'Kenford', 51),
# ('China', 'Etan', 'Burn', 53),
# ('Russia', 'Merralee', 'Chaperlin', 38),
# ('Indonesia', 'Lanny', 'Malam', 49),
# ('Canada', 'Wilhelm', 'Deeprose', 54),
# ('Czech Republic', 'Lari', 'Hillhouse', 48),
# ('China', 'Ossie', 'Woodley', 52),
# ('Macedonia', 'April', 'Tyer', 50),
# ('Vietnam', 'Madelon', 'Dansey', 53),
# ('Ukraine', 'Korella', 'McNamee', 52),
# ('Jamaica', 'Linnea', 'Cannam', 43),
# ('China', 'Mart', 'Coling', 52),
# ('Indonesia', 'Marna', 'Causbey', 47),
# ('China', 'Berni', 'Daintier', 55),
# ('Poland', 'Cynthia', 'Hassell', 49),
# ('Canada', 'Carma', 'Schule', 49),
# ('Indonesia', 'Malia', 'Blight', 48),
# ('China', 'Paulo', 'Seivertsen', 47),
# ('Niger', 'Kaylee', 'Hearley', 54),
# ('Japan', 'Maure', 'Jandak', 46),
# ('Argentina', 'Foss', 'Feavers', 45),
# ('Venezuela', 'Ron', 'Leggitt', 60),
# ('Russia', 'Flint', 'Gokes', 40),
# ('China', 'Linet', 'Conelly', 52),
# ('Philippines', 'Nikolas', 'Birtwell', 57),
# ('Australia', 'Eduard', 'Leipelt', 53)
# Out:
#    sqlite:///HR.db
#  * sqlite:///SQLiteMagic.db
# Done.
# 99 rows affected.
# []

# %% [markdown]
# ##Using Python Variables in your SQL Statements
# You can use python variables in your SQL statements by adding a ":" prefix to your python variable names.
# For example, if I have a python variable country with a value of "Canada", I can use this variable in a SQL query to find all the rows of students from Canada

# %%
country = "Canada"
# %sql select * from INTERNATIONAL_STUDENT_TEST_SCORES where country = :country
# Out:
#    sqlite:///HR.db
#  * sqlite:///SQLiteMagic.db
# Done.
# [('Canada', 'Cristionna', 'Wadmore', 46),
#  ('Canada', 'Wilhelm', 'Deeprose', 54),
#  ('Canada', 'Carma', 'Schule', 49)]

# %% [markdown]
# ## the Results of Queries to Python Variables
# You can use the normal python assignment syntax to assign the results of your queries to python variables.
# For example, I have a SQL query to retrieve the distribution of test scores (i.e. how many students got each score). I can assign the result of this query to the variable test_score_distribution using the = operator.

# %%
test_score_distribution = %sql SELECT test_score as "Test_Score", count(*) as "Frequency" from INTERNATIONAL_STUDENT_TEST_SCORES GROUP BY test_score;
test_score_distribution
# Out:
#    sqlite:///HR.db
#  * sqlite:///SQLiteMagic.db
# Done.
# [(38, 2),
#  (40, 1),
#  (43, 2),
#  (44, 2),
#  (45, 8),
#  (46, 7),
#  (47, 4),
#  (48, 14),
#  (49, 8),
#  (50, 10),
#  (51, 8),
#  (52, 8),
#  (53, 8),
#  (54, 5),
#  (55, 4),
#  (56, 1),
#  (57, 2),
#  (58, 4),
#  (60, 1)]

# %% [markdown]
# ##Converting Query Results to DataFrames
# You can easily convert a SQL query result to a pandas dataframe using the DataFrame() method. Dataframe objects are much more versatile than SQL query result objects. For example, we can easily graph our test score distribution after converting to a dataframe.

# %%
dataframe = test_score_distribution.DataFrame()

# %matplotlib inline
# uncomment the following line if you get an module error saying seaborn not found
# !pip install seaborn==0.9.0
import seaborn

plot = seaborn.barplot(x='Test_Score',y='Frequency', data=dataframe)

# %%
# %%sql
#
# --Feel free to experiment with the data set provided in this notebook for practice:
# SELECT country, first_name, last_name, test_score FROM INTERNATIONAL_STUDENT_TEST_SCORES;
# Out:
#    sqlite:///HR.db
#  * sqlite:///SQLiteMagic.db
# Done.
# [('United States', 'Marshall', 'Bernadot', 54),
#  ('Ghana', 'Celinda', 'Malkin', 51),
#  ('Ukraine', 'Guillermo', 'Furze', 53),
#  ('Greece', 'Aharon', 'Tunnow', 48),
#  ('Russia', 'Bail', 'Goodwin', 46),
#  ('Poland', 'Cole', 'Winteringham', 49),
#  ('Sweden', 'Emlyn', 'Erricker', 55),
#  ('Russia', 'Cathee', 'Sivewright', 49),
#  ('China', 'Barny', 'Ingerson', 57),
#  ('Uganda', 'Sharla', 'Papaccio', 55),
#  ('China', 'Stella', 'Youens', 51),
#  ('Poland', 'Julio', 'Buesden', 48),
#  ('United States', 'Tiffie', 'Cosely', 58),
#  ('Poland', 'Auroora', 'Stiffell', 45),
#  ('China', 'Clarita', 'Huet', 52),
#  ('Poland', 'Shannon', 'Goulden', 45),
#  ('Philippines', 'Emylee', 'Privost', 50),
#  ('France', 'Madelina', 'Burk', 49),
#  ('China', 'Saunderson', 'Root', 58),
#  ('Indonesia', 'Bo', 'Waring', 55),
#  ('China', 'Hollis', 'Domotor', 45),
#  ('Russia', 'Robbie', 'Collip', 46),
#  ('Philippines', 'Davon', 'Donisi', 46),
# ...

# %%
from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4606c73d-381b-4c9c-ac46-0aa7c2107d57" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4606c73d-381b-4c9c-ac46-0aa7c2107d57">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = pd.read_csv('mcdonaldata.csv')

# %%
conn = sqlite3.connect('McDonalds.db')

# %%
data.to_sql('MCDONALDS_NUTRITION', conn)#agoa criamos tabela no banco de dados
# Out:
# 141

# %%
df = pd.read_sql('SELECT * FROM MCDONALDS_NUTRITION', conn)
print(df)
# Out:
#      index  Unnamed: 0                    item servesize calories  protien  \
# 0        0           0         McVeggie Burger      168       402    10.24
# 1        1           1     McAloo Tikki Burger      146       339     8.50
# 2        2           2  McSpicy Paneer Burger      199       652    20.29
# 3        3           3       Spicy Paneer Wrap      250       674    20.96
# 4        4           4     American Veg Burger      177       512    15.30
# ..     ...         ...                     ...       ...      ...      ...
# 136    136         136  Tomato Ketchup Sachets         8    11.23     0.08
# 137    137         137             Maple Syrup         3     86.4     0.00
# 138    138         138            Cheese Slice        14    51.03     3.06
# 139    139         139              Sweet Corn        40    45.08     1.47
# 140    140         140    Mixed Fruit Beverage       180    72.25     0.65
#
# ...

# %%
df.head(20)
# Out:
#     index  Unnamed: 0                                        item servesize  \
# 0       0           0                             McVeggie Burger      168
# 1       1           1                         McAloo Tikki Burger      146
# 2       2           2                      McSpicy Paneer Burger      199
# 3       3           3                           Spicy Paneer Wrap      250
# 4       4           4                         American Veg Burger      177
# 5       5           5                           Veg Maharaja Mac        306
# 6       6           6                    Green Chilli Aloo Naan p     132
# 7       7           7                                 Pizza Puff        87
# 8       8           8                          Mc chicken Burger       173
# 9       9           9                       FILLET-O-FISH Burger       136
# 10     10          10                    Mc Spicy Chicken Burger       186
# ...

# %%
df.describe(include= 'all')
# Out:
#              index  Unnamed: 0             item servesize calories  \
# count   141.000000  141.000000              141       141      141
# unique         NaN         NaN              141       120      140
# top            NaN         NaN  McVeggie Burger      299     12.87
# freq           NaN         NaN                1         3        2
# mean     70.000000   70.000000              NaN       NaN      NaN
# std      40.847277   40.847277              NaN       NaN      NaN
# min       0.000000    0.000000              NaN       NaN      NaN
# 25%      35.000000   35.000000              NaN       NaN      NaN
# 50%      70.000000   70.000000              NaN       NaN      NaN
# 75%     105.000000  105.000000              NaN       NaN      NaN
# max     140.000000  140.000000              NaN       NaN      NaN
#
#            protien    totalfat      satfat    transfat  cholestrol  \
# count   141.000000  141.000000  141.000000  141.000000  141.000000
# ...

# %% [markdown]
# ##Qual alimento tem o maior teor de sódio do cardapio?

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ##CATEGORICAL SCATTERPLOT

# %%
plot = sns.swarmplot(x="menu", y='sodium', data=df)
plt.setp(plot.get_xticklabels(), rotation = 50)
plt.title('Sodium Content')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 25.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 5.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 33.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 11.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
plot = sns.swarmplot(x="menu", y='sugar', data=df)
plt.setp(plot.get_xticklabels(), rotation = 50)
plt.title('Sugar Content')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 16.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 22.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
plot = sns.swarmplot(x="menu", y='addedsugar', data=df)
plt.setp(plot.get_xticklabels(), rotation = 50)
plt.title('Added Sugar Content')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 33.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 31.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 38.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 35.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
df['sodium'].describe()
# Out:
# count     141.000000
# mean      362.918809
# std       477.792553
# min         0.000000
# 25%        41.990000
# 50%       150.900000
# 75%       530.540000
# max      2399.490000
# Name: sodium, dtype: float64

# %%
#para achar o index do ponto maximo de sodium do dataset.
df['sodium'].idxmax()
# Out:
# 18

# %%
#entao vamos trazê-lo
df.at[18,'item']
# Out:
# 'Ghee Rice with Mc Spicy Fried Chicken 1 pc'

# %%
df.head(2)
# Out:
#    index  Unnamed: 0                 item servesize calories  protien  \
# 0      0           0      McVeggie Burger      168       402    10.24
# 1      1           1  McAloo Tikki Burger      146       339     8.50
#
#    totalfat  satfat  transfat  cholestrol  carbs  sugar  addedsugar  sodium  \
# 0     13.83    5.34      0.16        2.49  56.54   7.90        4.49  706.13
# 1     11.31    4.27      0.20        1.47   5.27   7.05        4.07  545.34
#
#       menu
# 0  regular
# 1  regular

# %%
plot = sns.jointplot(x="protien", y='totalfat',data=df)
plt.show()

# %%
df['sugar'].describe()
# Out:
# count    141.000000
# mean      15.409504
# std       15.674007
# min        0.000000
# 25%        2.280000
# 50%        9.160000
# 75%       26.950000
# max       64.220000
# Name: sugar, dtype: float64

# %%
plot = sns.set_style("whitegrid")
ax = sns.boxplot(x=df["sugar"])
plt.show()

# %% [markdown]
# Da esquerda para a direita ,o braço da esquerda mostra o 1º quartil, dentro da caixa até a linha preta é o 2º quartil, até o final da caixa é o 3º quartil, o braço da direita é o 4º quartil e os pontos fora são OUTLIERS.
#
# JUSTAMENTE O PONTO MAXIMO DE 64 PARA SUGAR.

# %% [markdown]
# ##FIM
